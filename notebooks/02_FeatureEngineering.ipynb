# %% [markdown]
# 1. Instalacja pakietów

# %%
# %pip install Scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

dtype_dict = {
    'Store': int,
    'DayOfWeek': int,
    'Date': object,
    'Sales': int,
    'Customers': int,
    'Open': bytes,
    'Promo': bytes,
    'StateHoliday': str,
    'SchoolHoliday': int
}

df = pd.read_csv('../data/preprocessed/sales_store.csv',dtype = dtype_dict)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Unnamed: 0                 1017209 non-null  int64
#  1   Store                      1017209 non-null  int64
#  2   DayOfWeek                  1017209 non-null  int64
#  3   Date                       1017209 non-null  object
#  4   Sales                      1017209 non-null  int64
#  5   Customers                  1017209 non-null  int64
#  6   Open                       1017209 non-null  object
#  7   Promo                      1017209 non-null  object
#  8   StateHoliday               1017209 non-null  object
#  9   SchoolHoliday              1017209 non-null  int64
#  10  day_of_week                1017209 non-null  int64
#  11  month                      1017209 non-null  int64
#  12  StoreType                  1017209 non-null  object
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                        0
# Store                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# day_of_week                       0
# month                             0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# dtype: int64

# %%
df['PromoInterval'].unique()
# Out:
# array(['Mar,Jun,Sept,Dec', nan, 'Feb,May,Aug,Nov', 'Jan,Apr,Jul,Oct'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Unnamed: 0                 1017209 non-null  int64
#  1   Store                      1017209 non-null  int64
#  2   DayOfWeek                  1017209 non-null  int64
#  3   Date                       1017209 non-null  object
#  4   Sales                      1017209 non-null  int64
#  5   Customers                  1017209 non-null  int64
#  6   Open                       1017209 non-null  object
#  7   Promo                      1017209 non-null  object
#  8   StateHoliday               1017209 non-null  object
#  9   SchoolHoliday              1017209 non-null  int64
#  10  day_of_week                1017209 non-null  int64
#  11  month                      1017209 non-null  int64
#  12  StoreType                  1017209 non-null  object
# ...

# %%
#df= pd.get_dummies(df, columns=['StoreType'])
#df= pd.get_dummies(df, columns=['StateHoliday'])
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# Store                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# day_of_week                       0
# month                             0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# Year                              0
# Month                             0
# WeekOfYear                        0
# Day                               0
# IsWeekend                         0
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['WeekOfYear'] = df['Date'].dt.isocalendar().week
df['DayOfWeek'] = df['Date'].dt.dayofweek
df['Day'] = df['Date'].dt.day
df['IsWeekend'] = (df['DayOfWeek'] >= 5).astype(int)
df
# Out:
#          Unnamed: 0  Store  DayOfWeek       Date  Sales  Customers Open Promo  \
# 0                 0   1115          1 2013-01-01      0          0    0     0
# 1                 1    379          1 2013-01-01      0          0    0     0
# 2                 2    378          1 2013-01-01      0          0    0     0
# 3                 3    377          1 2013-01-01      0          0    0     0
# 4                 4    376          1 2013-01-01      0          0    0     0
# ...             ...    ...        ...        ...    ...        ...  ...   ...
# 1017204     1017204    746          4 2015-07-31   9082        638    1     1
# 1017205     1017205    747          4 2015-07-31  10708        826    1     1
# 1017206     1017206    748          4 2015-07-31   7481        578    1     1
# 1017207     1017207    742          4 2015-07-31  10460       1016    1     1
# 1017208     1017208      1          4 2015-07-31   5263        555    1     1
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df['Sales','Year'])  # X - Twoje cechy
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/nauka/sales-forecasting-project/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Sales', 'Year')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 4
# ...
